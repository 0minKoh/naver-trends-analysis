# %%
import pandas as pd

df_라코스테 = pd.read_csv('../res/라코스테.csv')
df_라코스테.set_index('date', inplace=True)
df_라코스테.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2100 entries, 2019-01-01 to 2024-09-30
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2100 non-null   int64
#  1   라코스테           2100 non-null   float64
#  2   라코스테_absolute  2100 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 65.6+ KB

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.plot(df_라코스테['라코스테_absolute'])
plt.xticks(ticks=range(0, len(df_라코스테), 365)) 
plt.show()
